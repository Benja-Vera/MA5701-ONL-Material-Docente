# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
n = 10
rho = 2  # kg / m
l = 0.5  # m
lam = 5  # más relevante la deformación que la masa

x = np.array([(2*lam / rho*l)**(1/3) * (1 - i/(n+1))**(4/3) for i in range(1, n+1)])
plt.plot(x, ".")
